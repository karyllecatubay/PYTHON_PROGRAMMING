# %% [markdown]
# # Numbers & Math #

# %% [markdown]
# ## Review Question 1

# %%
num1 = 25000000
num2 = 25_000_000

print(num1)
print(num2)
# Out:
# 25000000
# 25000000

# %%
num = 1.75e5
print(num)
# Out:
# 175000.0

# %%
N = 0

while True:
    x = float(f"2e{N}")  # 
    if x == float("inf"):  
        break
    N += 1  

print("The smallest N where 2eN becomes infinity:", N)
# Out:
# The smallest N where 2eN becomes infinity: 308

# %% [markdown]
# ## Review Question 2

# %%
base = float(input("Enter a base: "))
exp = float(input("Enter an exponent: "))
print(f"{base} to the power of {int(exp)} = {base ** exp}")
# Out:
# Enter a base:  1.2
# Enter an exponent:  3
# 1.2 to the power of 3 = 1.7279999999999998

# %% [markdown]
# ## Review Question 3

# %%
num = float(input("Enter a number: "))

round_num = round(num,2)

print((f"{num} rounded to 2 decimal places is {round_num}"))
# Out:
# Enter a number:  5.432
# 5.432 rounded to 2 decimal places is 5.43

# %%
num = float(input("Enter a number: "))

value = abs(num)

print(f"The absolute value of {int(num)} is {value}")
# Out:
# Enter a number:  -10
# The absolute value of -10 is 10.0

# %% [markdown]
# ## Review Question 4

# %%
first_num = float(input("Enter a number: "))
sec_num = float(input("Enter another number: "))

difference = first_num - sec_num
is_integer = difference.is_integer()

print(f"The difference between {text1} and {text2} is an integer? {is_integer}!")
# Out:
# Enter a number:  1.5
# Enter another number:  .5
# The difference between 1.5 and 1.0 is an integer? True!

# %% [markdown]
# ## Review Question 5

# %%
result = 3 ** .125
print(f"{result:.3f}")
# Out:
# 1.147

# %%
currency = 150000
print(f"{currency:,.2f}")
# Out:
# 150,000.00

# %%
result = 2/10
print(f"{result:.0%}")
# Out:
# 20%
