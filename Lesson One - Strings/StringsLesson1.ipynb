# %% [markdown]
# ## Review Question 1 #

# %%
word = "python programming"
len(word)
# Out:
# 18

# %%
string1 = "first"
string2 = "aid"
word = string1+string2 
print(word)
# Out:
# firstaid

# %%
string1 = "first"
string2 = "aid"
word = string1+ " " +string2 
print(word)
# Out:
# first aid

# %%
text = "The quick brown fox jumped over the lazy dog. #1234567890!"
result = text[0:19]
print(result)
# Out:
# The quick brown fox

# %% [markdown]
# ## Review Question 2

# %%
word1 = "Animals"
word2 = "Badger"
word3 = "Honey Bee"
word4 = "Honeybadger"

print(word1.lower())
print(word2.lower())
print(word3.lower())
print(word4.lower())
# Out:
# animals
# badger
# honey bee
# honeybadger

# %%
word1 = "Animals"
word2 = "Badger"
word3 = "Honey Bee"
word4 = "Honeybadger"

print(word1.upper())
print(word2.upper())
print(word3.upper())
print(word4.upper())
# Out:
# ANIMALS
# BADGER
# HONEY BEE
# HONEYBADGER

# %%
string1 = " Filet Mignon"
string2 = "Brisket "

string1 = string1.lstrip()
string2 = string2.rstrip()

print(string1) 
print(string2)
# Out:
# Filet Mignon
# Brisket

# %%
string1 = "Becomes"
string2 = "becomes"

print(string1.startswith("be"))
print(string2.startswith("be"))
# Out:
# False
# True

# %%
string1 = "Becomes"
string2 = "becomes"

string1 = string1.lower()
string2 = string2.lower()

print(string1.startswith("be"))
print(string2.startswith("be"))
# Out:
# True
# True

# %% [markdown]
# ## Review Question 3

# %%
text = input("Write something:")
print(text)
# Out:
# Write something: Hello World
# Hello World

# %%
text = input("Write something:")
print(text.lower())
# Out:
# Write something: HELLO WORLD
# hello world

# %%
text = input("Write something:")
print("Number of characters:", len(text))
# Out:
# Write something: Hello World
# Number of characters: 11

# %% [markdown]
# ## Review Question 4

# %%
name = input("Tell me your name: ").strip()

if name:
    first_letter = name[0].upper()
    print("First letter of your name is:", first_letter)
else:
    print("You didn't enter a name.")
# Out:
# Tell me your name:  karylle
# First letter of your name is: K

# %% [markdown]
# ## Review Question 5

# %%
num_str = "50"
num_int = int(num_str)
result = num_int * 10
result
# Out:
# 500

# %%
num_str = "12.0"
num_float = float(num_str)
result = num_float * 10
result
# Out:
# 120.0

# %%
name = "Ben"
num = 10

print(name+ " " +str(num))
# Out:
# Ben 10

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

result = num1 * num2

if result.is_integer():
    result = int(result)
    
print("The result is:", result)
# Out:
# Enter first number:  5
# Enter second number:  2
# The result is: 10

# %% [markdown]
# ## Review Question 6

# %%
print("AAA".find("a"))
# Out:
# -1

# %%
string = "Somebody said something to Samantha."
string = string.lower()
string = string.replace("s", "y")
print(string)
# Out:
# yomebody yaid yomething to yamantha.

# %%
text = input("Enter something: ")

letter = input("Enter a letter to find: ")

position = text.find(letter)

print("Result of .find():", position)
# Out:
# Enter something:  Somebody said something to Samantha
# Enter a letter to find:  a
# Result of .find(): 10

# %% [markdown]
# ## Review Question 7

# %%
text = input("Enter some text: ")

text = text.replace("a", "4")
text = text.replace("b", "8")
text = text.replace("e", "3")
text = text.replace("l", "1")
text = text.replace("o", "0")
text = text.replace("s", "5")
text = text.replace("t", "7")

print(text)
# Out:
# Enter some text:  The cat sat on the mat.
# Th3 c47 547 0n 7h3 m47.
